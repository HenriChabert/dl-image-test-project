# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# Read recipe inputs
folder_with_no_images = dataiku.Folder("lIxqSc0T")
folder_with_no_images_info = folder_with_no_images.get_info()

# %%
folder_with_no_images.list_paths_in_partition()
# Out:
# [u'/backend_2021_01_12.log',
#  u'/model_info (2).json',
#  u'/ice-water-vapor-fact-or-fiction.html',
#  u'/text-metadata.csv',
#  u'/cercle-du-cycle-des-quintes.pdf',
#  u'/PLUGINTESTNEARESTNEIGHBOURSSEARCH/FuOm82pI/2020-10-14 11:50:37.768514_annoy/canary.txt',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/solar-energy/metadata.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/solar-energy/train/data.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/solar-energy/test/data.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/electricity/metadata.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/electricity/train/data.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/electricity/test/data.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/traffic/metadata.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/traffic/train/data.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/traffic/test/data.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/m4_hourly/metadata.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/m4_hourly/train/data.json',
#  u'/GLUONTSBENCHMARK/6mJzHSAC/m4_hourly/test/data.json',
# ...

# %%
for f in folder_with_no_images.list_paths_in_partition():
    tf = folder_with_no_images.get_download_stream(f)
