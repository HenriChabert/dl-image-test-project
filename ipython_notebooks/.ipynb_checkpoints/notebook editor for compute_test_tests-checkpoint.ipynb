# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu
import re

# Read recipe inputs
classified_images = dataiku.Dataset("classified_images")
classified_images_df = classified_images.get_dataframe()

# %%
correct_classif = [re.split["(_.)"]classified_images_df['images'].value
# Out:
#             images                          prediction  error
# 0      /2_lion.jpg        {"lion": 0.9025413990020752}      0
# 1     /1_tiger.jpg       {"tiger": 0.8765539526939392}      0
# 2      /4_lion.jpg        {"lion": 0.9820299744606018}      0
# 3      /3_lion.jpg        {"lion": 0.9987598657608032}      0
# 4     /2_tiger.jpg        {"tiger": 0.902034342288971}      0
# 5     /4_tiger.jpg        {"tiger": 0.709359884262085}      0
# 6     /5_tiger.jpg       {"tiger": 0.6957002878189087}      0
# 7     /6_tiger.jpg       {"tiger": 0.8612405061721802}      0
# 8      /6_lion.jpg        {"lion": 0.9999206066131592}      0
# 9     /8_tiger.jpg       {"tiger": 0.8114100694656372}      0
# 10     /9_lion.jpg        {"lion": 0.9025336503982544}      0
# 11   /9_tiger.jpeg       {"tiger": 0.9146807193756104}      0
# 12   /10_tiger.jpg       {"tiger": 0.8749715089797974}      0
# 13    /10_lion.jpg        {"lion": 0.9996740818023682}      0
# ...

# %%
re.p"(_.)"
